# %%
cd ..

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_parquet("artifacts/data/output/train.parquet")
train_df
# Out:
#          case_id date_decision   MONTH  WEEK_NUM  target dateofbirth gender  \
# 1202988  1797017    2020-02-24  202002        59       0  1990-04-01      M
# 733770   1327799    2019-04-01  201904        12       0  1995-01-01      F
# 699565   1293594    2019-02-25  201902         7       0  1955-06-01      F
# 620510   1005043    2020-08-16  202008        84       0  1986-01-01      F
# 1213702  1807731    2020-03-07  202003        61       0  1993-05-01      F
# ...          ...           ...     ...       ...     ...         ...    ...
# 117836    163270    2019-09-30  201909        38       0  1957-01-01      F
# 1051587  1645616    2019-11-23  201911        46       0  1985-01-01      F
# 433541    818074    2019-10-01  201910        39       0  1989-03-01      F
# 1014068  1608097    2019-11-02  201911        43       0  1989-11-01      F
# 532307    916840    2019-12-29  201912        51       0  1995-06-01      F
#
# ...

# %%
train_df.target.value_counts().plot(
    kind = "bar",
    title = "Distribution of credit cases by gender",
    xlabel = "gender",
    ylabel = "count",
    color = "grey"
)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
train_df.marital_status.value_counts().plot(
    kind = "bar",
    title = "Distribution of credit cases by marital status",
    xlabel = "marital status",
    ylabel = "count",
)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
train_df.income.plot(
    kind = "hist",
    title = "Distribution of credit cases by income",
    xlabel = "income",
    ylabel = "count",
    color = "grey"
)
